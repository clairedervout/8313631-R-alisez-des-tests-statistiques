# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Test de Pearson

# %%
from scipy.stats import pearsonr

# %%
df = pd.read_csv('/content/Données entreprise Vertigo nettoyées - Feuille 1.csv')

# %%
df.columns
# Out:
# Index(['Date', 'Nombre_de_Clients', 'Revenu_des_Ventes',
#        'Depenses_Publicitaires', 'Nombre_de_Reservations'],
#       dtype='object')

# %%
df.head()
# Out:
#        Date  Nombre_de_Clients  Revenu_des_Ventes  Depenses_Publicitaires  \
# 0  01/01/23                 54               5587                    4817
# 1  02/01/23                 48               4697                    6374
# 2  03/01/23                 56               5619                    4354
# 3  04/01/23                 65               6408                    4200
# 4  05/01/23                 47               4614                    4517
#
#    Nombre_de_Reservations
# 0                     226
# 1                     321
# 2                     207
# 3                     205
# 4                     258

# %%
depenses = df['Depenses_Publicitaires']
reservations = df['Nombre_de_Reservations']

# %%
sns.regplot(x=depenses, y=reservations, robust=True, line_kws=dict(color="r"))
# Out:
# <Axes: xlabel='Depenses_Publicitaires', ylabel='Nombre_de_Reservations'>

# %%
correlation, p_value = pearsonr(depenses, reservations)

print(f"Coefficient de corrélation de Pearson: {correlation}")
print(f"Valeur p: {p_value}")
# Out:
# Coefficient de corrélation de Pearson: 0.9260102639258713
# Valeur p: 0.0
